# %%
# -*- coding: utf-8 -*-
"""bart.ipynb

Automatically generated by Colaboratory.

Original file is located at
    https://colab.research.google.com/drive/1J2GpbAAQtHXt3MmcmfVt8aiQ8aSYAMWH
"""

# %%
# This run uses Pytorch Lightening to finetune the model
# !pip install -q pytorch-lightning
# !pip install git+https://github.com/huggingface/transformers

# %%
# imports
import transformers
from torch.utils.data import DataLoader, TensorDataset, random_split, RandomSampler, Dataset
import pandas as pd
import numpy as np
import os

import torch.nn.functional as F
import pytorch_lightning as pl
import torch
from pytorch_lightning.callbacks import ModelCheckpoint

import math
import random
import re
import argparse

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
root_dir = "/content/drive/MyDrive/"
base_dir = root_dir + 'CS425-NLP project/datasets/BART_input.csv'
save_dir = root_dir + 'CS425-NLP project/datasets/BART-dialogue generation/'
checkpoint_dir = root_dir + 'CS425-NLP project/bart_saved_model'
# Out:
# Mounted at /content/drive

# %%
conversation_dataset = pd.read_csv(base_dir)

# %%
display(conversation_dataset)
# Out:
#                                                   seeker  \
# 0      I like acting, I hope to be an actor, what abo...
# 1                                       No, but someday.
# 2      After I am done with school I plan to have a f...
# 3                      I hope so, how old are your kids?
# 4          I would imagine. I am sure they a great kids.
# ...                                                  ...
# 31073  Yes, but this time I do not think that I was d...
# 31074  Exactly.  I drank some warm milk, hoping that ...
# 31075  I am sorry to hear that.  Have you tried drink...
# 31076  The other thing that you might try to calm you...
# 31077  Yes, it will.  I was very sick with a stomach ...
#
#                                                supporter
# 0                             I do too. Wat do you like?
# 1                            that is ok.  have any kids?
# 2                                 that is good. I have 2
# 3                       that is great! you will be ready
# 4                  5 & 7.  they take up a lot of my time
# ...                                                  ...
# 31073  Did you feel like you were not really asleep? ...
# 31074  Well, mine does that sometimes too when I drin...
# 31075  I haven't tried that but I might because I dri...
# 31076  Will it help my being so bloated? My stomach f...
# 31077  I hope you get to feeling better and I will tr...
#
# [31078 rows x 2 columns]

# %%
class LitModel(pl.LightningModule):
  # Instantiate the model
  def __init__(self, learning_rate, tokenizer, model, hparams):
    super().__init__()
    self.tokenizer = tokenizer
    self.model = model
    self.learning_rate = learning_rate
    self.hp = hparams
  
  def freeze_embeds(self):
    ''' freeze the positional embedding parameters of the model; adapted from finetune.py '''
    freeze_params(self.model.model.shared)
    for d in [self.model.model.encoder, self.model.model.decoder]:
      freeze_params(d.embed_positions)
      freeze_params(d.embed_tokens)

  # Do a forward pass through the model
  def forward(self, input_ids, **kwargs):
    return self.model(input_ids, **kwargs)
  
  def configure_optimizers(self):
    optimizer = torch.optim.Adam(self.parameters(), lr = self.learning_rate)
    return optimizer

  def training_step(self, batch, batch_idx): 
    # Load the data into variables
    src_ids, src_mask = batch[0], batch[1]
    tgt_ids = batch[2]
    # Shift the decoder tokens right (but NOT the tgt_ids)
    decoder_input_ids = shift_tokens_right(tgt_ids, tokenizer.pad_token_id)

    # Run the model and get the logits
    outputs = self(src_ids, attention_mask=src_mask, decoder_input_ids=decoder_input_ids, use_cache=False)
    lm_logits = outputs[0]
    # Create the loss function
    ce_loss_fct = torch.nn.CrossEntropyLoss(ignore_index=self.tokenizer.pad_token_id)
    # Calculate the loss on the un-shifted tokens
    loss = ce_loss_fct(lm_logits.view(-1, lm_logits.shape[-1]), tgt_ids.view(-1))

    return {'loss':loss}

  def validation_step(self, batch, batch_idx):

    src_ids, src_mask = batch[0], batch[1]
    tgt_ids = batch[2]

    decoder_input_ids = shift_tokens_right(tgt_ids, tokenizer.pad_token_id)
    
    # Run the model and get the logits
    outputs = self(src_ids, attention_mask=src_mask, decoder_input_ids=decoder_input_ids, use_cache=False)
    lm_logits = outputs[0]

    ce_loss_fct = torch.nn.CrossEntropyLoss(ignore_index=self.tokenizer.pad_token_id)
    val_loss = ce_loss_fct(lm_logits.view(-1, lm_logits.shape[-1]), tgt_ids.view(-1))

    return {'loss': val_loss}
  
  # Method that generates text using the BartForConditionalGeneration's generate() method
  def generate_text(self, text, eval_beams, early_stopping = True, max_len = 40):
    """ Function to generate text """
    generated_ids = self.model.generate(
        text["input_ids"],
        attention_mask=text["attention_mask"],
        use_cache=True,
        decoder_start_token_id = self.tokenizer.pad_token_id,
        num_beams= eval_beams,
        max_length = max_len,
        early_stopping = early_stopping
    )
    return [self.tokenizer.decode(w, skip_special_tokens=True, clean_up_tokenization_spaces=True) for w in generated_ids]

def freeze_params(model):
  """ Function that takes a model as input (or part of a model) and freezes the layers for faster training """
  for layer in model.parameters():
    layer.requires_grade = False

# %%
# Create a dataloading module as per the PyTorch Lightning Docs
class SummaryDataModule(pl.LightningDataModule):
  def __init__(self, tokenizer, data_file, batch_size, num_examples = 20000):
    super().__init__()
    self.tokenizer = tokenizer
    self.data_file = data_file
    self.batch_size = batch_size
    self.num_examples = num_examples
  
  # Loads and splits the data into training, validation and test sets with a 60/20/20 split
  def prepare_data(self):
    self.data = pd.read_csv(self.data_file, lineterminator='\n')[:self.num_examples]
    self.train, self.validate, self.test = np.split(self.data.sample(frac=1), [int(.6*len(self.data)), int(.8*len(self.data))])

  # encode the sentences using the tokenizer  
  def setup(self, stage):
    print(self.train)
    self.train = encode_sentences(self.tokenizer, self.train['seeker'], self.train['supporter'])
    self.validate = encode_sentences(self.tokenizer, self.validate['seeker'], self.validate['supporter'])
    self.test = encode_sentences(self.tokenizer, self.test['seeker'], self.test['supporter'])

  # Load the training, validation and test sets in Pytorch Dataset objects
  def train_dataloader(self):
    dataset = TensorDataset(self.train['input_ids'], self.train['attention_mask'], self.train['labels'])                          
    train_data = DataLoader(dataset, sampler = RandomSampler(dataset), batch_size = self.batch_size)
    return train_data

  def val_dataloader(self):
    dataset = TensorDataset(self.validate['input_ids'], self.validate['attention_mask'], self.validate['labels']) 
    val_data = DataLoader(dataset, batch_size = self.batch_size)                       
    return val_data

  def test_dataloader(self):
    dataset = TensorDataset(self.test['input_ids'], self.test['attention_mask'], self.test['labels']) 
    test_data = DataLoader(dataset, batch_size = self.batch_size)                   
    return test_data

# %%
# Create the hparams dictionary to pass in the model
hparams = argparse.Namespace()
hparams.freeze_encoder = True
hparams.freeze_embeds = True
hparams.eval_beams = 4

# %%
def shift_tokens_right(input_ids, pad_token_id):
  """ Shift input ids one token to the right, and wrap the last non pad token (usually <eos>). """
  prev_output_tokens = input_ids.clone()
  index_of_eos = (input_ids.ne(pad_token_id).sum(dim=1) - 1).unsqueeze(-1)
  prev_output_tokens[:, 0] = input_ids.gather(1, index_of_eos).squeeze()
  prev_output_tokens[:, 1:] = input_ids[:, :-1]
  return prev_output_tokens

def encode_sentences(tokenizer, source_sentences, target_sentences, max_length=32, pad_to_max_length=True, return_tensors="pt"):
  """ Function that tokenizes a sentence 
      Args: tokenizer - the BART tokenizer; source and target sentences are the source and target sentences
      Returns: Dictionary with keys: input_ids, attention_mask, target_ids
  """

  input_ids = []
  attention_masks = []
  target_ids = []
  tokenized_sentences = {}

  for sentence in source_sentences: 
    print(sentence)

  for sentence in source_sentences:
    encoded_dict = tokenizer(
          sentence,
          max_length=max_length,
          padding="max_length" if pad_to_max_length else None,
          truncation=True,
          return_tensors=return_tensors,
          add_prefix_space = True
      )

    input_ids.append(encoded_dict['input_ids'])
    attention_masks.append(encoded_dict['attention_mask'])

  input_ids = torch.cat(input_ids, dim = 0)
  attention_masks = torch.cat(attention_masks, dim = 0)

  for sentence in target_sentences:
    encoded_dict = tokenizer(
          sentence,
          max_length=max_length,
          padding="max_length" if pad_to_max_length else None,
          truncation=True,
          return_tensors=return_tensors,
          add_prefix_space = True
      )
    target_ids.append(encoded_dict['input_ids'])

  target_ids = torch.cat(target_ids, dim = 0)
  

  batch = {
      "input_ids": input_ids,
      "attention_mask": attention_masks,
      "labels": target_ids,
  }

  return batch

# %%
# Load the model
from transformers import BartTokenizer, BartForConditionalGeneration, AdamW, BartConfig

tokenizer = BartTokenizer.from_pretrained('facebook/bart-base', add_prefix_space=True)

bart_model = BartForConditionalGeneration.from_pretrained("facebook/bart-base")
# Out:
# Downloading:   0%|          | 0.00/899k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.72k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/558M [00:00<?, ?B/s]

# %%
# Load the data into the model for training
summary_data = SummaryDataModule(tokenizer, base_dir, batch_size = 16, num_examples = 140000)

summary_data.data = pd.read_csv(summary_data.data_file, lineterminator='\n')[:summary_data.num_examples]
summary_data.train, summary_data.validate, summary_data.test = np.split(summary_data.data.sample(frac=1), [int(.6*len(summary_data.data)), int(.8*len(summary_data.data))])
display(summary_data.train)

summary_data.train = encode_sentences(summary_data.tokenizer, summary_data.train['seeker'], summary_data.train['supporter'])
summary_data.validate = encode_sentences(summary_data.tokenizer, summary_data.validate['seeker'], summary_data.validate['supporter'])
summary_data.test = encode_sentences(summary_data.tokenizer, summary_data.test['seeker'], summary_data.test['supporter'])


# Load the model from a pre-saved checkpoint; alternatively use the code below to start training from scratch
# model = LitModel.load_from_checkpoint(checkpoint_dir + "/epoch=2-step=11418.ckpt",
#                                       learning_rate = 2e-5, tokenizer = tokenizer, model = bart_model, hparams = hparams)

model = LitModel(2e-5, tokenizer, bart_model, hparams)

# %%
checkpoint = ModelCheckpoint(dirpath=save_dir + 'checkpoint_files/')
trainer = pl.Trainer(gpus = 1,
                     max_epochs = 3,
                     min_epochs = 1,
                     auto_lr_find = False,
                     callbacks=[checkpoint])
# Out:
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/trainer/connectors/accelerator_connector.py:447: LightningDeprecationWarning: Setting `Trainer(gpus=1)` is deprecated in v1.7 and will be removed in v2.0. Please use `Trainer(accelerator='gpu', devices=1)` instead.
#   f"Setting `Trainer(gpus={gpus!r})` is deprecated in v1.7 and will be removed"
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs

# %%
trainer.fit(model, summary_data)
# Out:
# WARNING:pytorch_lightning.loggers.tensorboard:Missing logger folder: /content/lightning_logs
# Streaming output truncated to the last 5000 lines.
# Me as well, that's awesome! Do you love art?
# i wonder if there even is life on other planets
# Well I like to pick up heavy stuff and throw it as far as I can. This time it landed on my bed. What do you do for fun?
# Sounds like a good idea!
# Nice! Do you have a large audience?
# What's the best thing you have cooked?
# i have spare cats , i'm a veterinarian , maybe that will do ?
# no , it is just me and the cats .
# I'm so excitied about going to my friend's big party tomorrow night! I really can't wait!
# That's a good way of reacting! I think it teaches you to not respond to situations with anger.
# anyone i have never been there
# sorry . i speak english as well . how are you ?
# Yeah me either, those aren't as interesting to watch.
# do you think i could live up to your standards
# what "inflatable things" would that be?
# Yeah, it's always more fun when you have a home crowd. What is your favorite sport?
# I clean aquariums and manage a hotel, also not glamorous.
# If I didnt take my self defense classes I feel like I would never been able to survive!
# definitely mate, where you live
# you seem like a very stubborn person
# I believe if was Night of the Living Dead!
# What's your favorite team?
# you are right but they have really good athletes
# I like to write my own songs, so it really helped me get through my health scare.
# I need more pots and pans too.
# I am a vegetarianism
# ok then...how much do they typically cost
# I finally got a time with my buddy to go camping in a couple weeks!
# Where do you volunteer at? I have been a nurse for a long time.
# I don't. I mostly play for weddings and special occasions as a soloist. What is the name of your jazz band?
# I am an accountant.
# I am a probation officer during the day, and i always wear black!
# My dog is 4 and my cat is 8
# I do think I will miss my mom but she will be fine she has tons of friends.
# my mom like to clean
# Geology? that sounds interesting what does it entail?
# I feel a bit down in the dumps now.
# I would think so too. That is why I hesitate being in the medical field.
# yeah sometimes it makes life difficult. my back is always very stiff
# Really. I have never watched
# Haha, well I hope the packers win! Give Tom Brady a ticket home. It was nice chatting with you!
# I do yoga and exercise classes at the gym. I like acrobatic stuff because I used to be a cheerleader.
# There is a version of Risk based on Star Wars that is fun.  We played it a lot this summer to avoid the heat.
# may be 100%.. what say?
# Sounds peaceful, though. What kind of animals did your parents keep?
# We would take at least one trip every summer. Sometimes to Las Vegas and other times out east. We always drove.
# what are you studying in school
# Well, it's been really nice talking to you!
# What else you like to do are you good at math?
# Thank you for your service then. I have family members who were in the armed services and it's very admirable.
# sounds good! my pet stays at my room, it's in the basement but pretty comfy
# Maybe but hopefully we all benefit and make money in the end.
# Wow, that's pretty interesting. What do you think of corn dogs? They're one of my favorite food items.
# What's your favourite type?
# have you ever been there?
# Yep, it's definitely challenging, especially for a young introvert like myself.
# oh yes he is a cutie
# I know the feeling, it's devastating and not to mention embarrassing.
# Very true. You can see it in the number of natural disasters all around. Have you been affected?
# It's cool because no day is the same. What are you into?
# that's awesome , my family are all military , so i followed suit
# You know, travel can be as cheap or as expensive as you want it to be. You can stay in hostels or do work studies
# Yes that is always a good idea to spend some time away from the electronics.  It's hard to do these days.
# I like plenty of cheese and BBQ when i have mine
# I'm graduting in the winter.
# yes first time for me, so I am excited
# I like to go to the gym, or go running down the beach.
# In my 53 years of being alive I've had it happen a handful of times and it irritates me.
# I haven't listened to much jazz. About me, I also own 3 dogs. Do you have any pets?
# He's the total package for sure, but I love my two kids more. Lol
# Thats great.Both my moms are supportive of my work all they want is for me to call and check in every now and then. Family is important.
# what is your band called? I want to hear you guys play.
# Last week I was told that I was near sighted a needed glasses.
# We made the decision to homeschool our girls years ago.
# Do you know any interesting facts about them?
# Do you like it?
# computer science research for a medical lab
# what area do you want to specialize in?
# Yea you got it, but yoga doesn't require much energy as swimming does.
# What kind of food do you like to cook?
# yeah theyre great, so many different experiences people have
# I have a white cat, he is really cute
# That sounds so cool! Are you happy when you draw them?
# Ooh thats cool, I think you should do that defenitely...I plan to go after I finish my college degree.
# I didn't have enough money to pay my rent last week.
# There's nothing wrong with being a little nerdy!
# yeah i love it
# I like walking at the park near my place.
# Oh, Area 51 is a military base. You'd have to start by joining the Air Force.
# Natural red hair is so beautiful.
# Pasta has always been my comfort food! And I can eat ice cream any time of year :)
# Where do you work at?
# ye si like so much
# Yeah! Have you got a preference on your tech? PC, apple? Desktop or tablet?
# Oh good! So it's a happy ending after all. I think my Prius should be ready at the shop. I better be going!
# Are you as overworked as the media says?
# I love it .It is my passion.What do you do for a living??
# i work in IT
# exactly, I am going try to get in contact with them about spending the holiday's with them again.
# Those are very yummy! Has the tomato been around since the beginning of time?
# All of it sounds the same and it's awful
# Ok! Let's do it!
# I drive out in my passat and get fast food at least once a day.
# Me too.  I have been putting in a lot of time lately, advertising and trying to build up business.
# Nice! Can't afford that type. Have an SUV myself.
# Do you have any dates planned?
# Yeah, it's cool to find out about other cultures.
# That's too bad. If you don't mind me asking, how come?
# Wow! How terrible! Are you an indoors or outdoors kind of person? I stay in all summer, But I LOVE being outside in winter.
# You have a bright future ahead of you.  I wish you the best of luck.
# Yeah. I love my dog, but I feel bad that I can't always give her all she needs.  Especially if a vet visit is involved
# i enjoy watching fighter jets in movies
# do you live in baltimore ?
# The problem is that lately my eyes started to hurt.
# A little bit of everything. My peppers are another favorite.
# Finance accounts..and uu...
# Awesome trying to make money and get your high school diploma.  What grade are you in?
# I don't think that personal lives should be up for discussion unless they've done something immoral, and sexuality is not immoral.
# I usually do. Give me a few drinks and I will have my own gathering. But I need to get ready for the academy.
# So true! I learned that some places can only be appreciated alone, and some experiences just don't have room for two.
# Sure, I'l be glad to take in a few tips for future references.
# No. I have a problem with my step dad but he ignored me all the time.
# Is that your favorite musician? Why were the cds coveted?  Can't  you replace them?
# That's impressive as well.  I used to do some biking, but I've gotten away from it.
# I know there are different colored belts depending on skill, but I only remember his last one was brown.
# They know a little bit that we have taught them over the years. My wife doesn't visit as much, so they rarely need to use it anymore.
# Sounds good, I should try those if I get a chance to visit Mexico, there so much green there I'm sure I would love it.
# Body piercing is something which we can't do
# I hate presenting a project in front of my class. It's so nerve-racking.
# I tried a new Mexican restaurant
# It would be tragic if you didn't take those extra days! Good if those days are at the end of the trip so you know your way around.
# That's awesome. I've never been to Europe. What was your favorite thing you did in Germany?
# good comparison ! ! that's actually a flattering comparison for me .
# Yes they are.  I had one growing up.  I would run a mile every morning and he would follow me every time.  Active dogs.
# I am familiar with country music.  Do you have a favorite artist?
# I agree, but I work two jobs so it's hard to find free time sometimes.
# That sounds like fun!
# i have only 2 siblings
# I don't think I would be into that. There would be too many people. I have social anxiety. And i'm a really quiet person
# What are the chances! Do you have any pets?
# I love anything with curry in it. My mother passed away, but she used to make the best lamb curry.
# That's reassuring. She's excited to be in a new creative writing class first period. I'm glad she takes after her mother, haha.
# Sand?  So you camp on the beach!  The kids and I love to go swimming.  You build sand castles?
# Big city life is much different than the country life
# So did you grow up with siblings or are you an only child as well?
# I sure hope not. I have enough savings for a month....maybe two. Then, I'm in trouble.
# I don't like animals either, their hair gets into everything.
# i believe rally racing is similar but involves motorsports but i will have to do more research
# What other books do you enjoy?
# I booked an AirBnB for our vacation this week. We just got here, and they forgot to mention a little detail about having a cat. My spouse and I are both very allergic to cats... We can't stay here now! And yet we're getting charged for cancelling, and we have to find a new hotel.
# Honestly, my favorite food is Pizza, but good pizza, not the usual pizza chain pizza
# darn, what do you do then?
# Yes it is amazing, and it is true that most animals seem to know how to swim without any learning involved.
# There's a restaurant I go to often with my family. After all these years, they're closing down.
# I have to take my daughter up to her school today to get her freshman high school schedule today.
# Mostly dogs and cats, but we have some birds and reptiles too. What do you do for work?
# I feel like there is so much more we could all do to help. What do you do for a living?
# my grandfather did. he was an awesome guy. he didnt talk to much about so he took up professional dog training
# I haven't either.  Sounds kinda gross
# I'm sure it will, so as a chef what aspirations do you have in terms of what country you would like to work in?
# It went great actually, she was very shy and blushed at me.
# That's like throwing a rock into a lake and hoping it hits something on the way down other then water! I'll keep my eyes open.
# Zombies?! Oh, what music do you like?
# they are the only thing important in our life
# Late last night I swore I heard some footsteps coming from my kitchen. I live alone and was convinced someone was in the house.
# What's your favorite dish to cook?
# No, I do not. I've had it before. May try it out again when I can afford to do so.
# yes it is! are you having a boy or girl?
# I love holidays, because I get to spend time at home with my pets. Do you have any pets?
# Those sound cool! I'd really like to get more. I love tattoos
# Indeed. So tell me about some of your life experiences.
# Wow, that sounds like an interesting job. Do you meet lots of new people through it?
# Me too it's just so hard to get my family on board but I definitely try to make more plant based meals these days!
# how is the weather ? it is very cold usually but spring is beautiful .
# Yea, he has alot and we really dont have room for them anymore.
# I've heard about stuff like that! It's insane the amount of ingredients that are in unhealthy processed foods like that.
# I really enjoy running in marathons
# lol, they really are.
# I can relate to that. There is not much to do here either. Especially since it's gotten cold.
# It sort of is. It feels much easier for women to find dates than men! I'm not sure why that is.
# I would like to experience it. When is the next night with a DJ?
# I'm sure you will be able to. Having a kind and empathetic influence on a child does a whole lot of good!
# swim swim swim little fish to the sea don't look back
# Is that the animated movie?
# maaaaayyyyybe, I don't know.  Seems like something the 1% would try to keep to themselves.
# Oh nice! What are some of your favorite dishes to cook?
# How do you balance your work life?
# lol big world out there. it's hard work and boring, but i'm my own boss.
# I see.  Do you play too?
# No more traffic jams. I'm sold. I wish traveling by train wasn't so expensive, though. Flying is ususally cheaper.
# I like to oil paint, but don't have much time for it.  I'm usually driving my kids around to their activities.  How about you?
# I like to go to Broadway shows. I love singing show tunes!
# Oh yes very rewarding and thats great! Does she like it?
# this is to help you with your studies , it is effective
# This is such a small world...you and I having the same fertility issues. Go Amazon! So where do you live?
# Yes, I work at a non-profit that helps children. Do you work?
# Oh, I started playing guitar because of The Beatles!  Twist and Shout, over and over again!  LOL
# My husband and I decided to get another dog. I was nervous to tell his parents about it.
# I agree, i'm a truck driver so often find myself hours from home or sleeping overnight in motels - it can be lonely at times
# I love green tea! Black tea is my favorite too though. I could drink it all day!
# I like how he makes me feel safe because I feel he is a workaholic and can address any problem night or day. Big culture war going on though.
# cool do you remember your number ? mine is 42
# i'm great ! relaxing after work by watching palladin ! how are you ?
# No, I am not interested in that either. Have you considered it?
# Yes! Especially fries from places like McDonalds
# But it also has lot's of carbs
# what kind of classical music do you enjoy ?
# 3, 5, 7
# OK, that sounds great.  i'll bring along a pair of our newest athletic shoes for you.
# i used to fight people in hockey all the time
# That's awesome, tell me about him / her
# I'm on a college budget so it's hard to buy healthy food. It's so much more expensive than the junk food is.
# Technology for those with disabilities has come a long way
# Yes, I actually work for IBM. What do you do for work?
# Yes, I am very happy.   Everything is good here.
# I've been fascinated with Japanese culture and speak some of the language.
# i'm good . i talk and type fast .
# do you like dentist?
# Thats a great dish! I love mexican cuisine especially tacos! i have a food truck in the neighborhood making the best ones!
# Hi! That is unfortunate. What do you do to try and combat the problem?
# I haven't read that. I need some new inspirations-I'll check it out.
# I aspire to be that lady! Shoes, handbags, and clothes.. who needs a best friend lol
# To be honest, my dog is the only reason I get exercise some days.
# did u hear about electronic music?
# I don't believe this generation has put out the kind of unique music that will be remembered in the future.
# That's excellent. Do you enjoy any particular venues or types of music?
# it help also when i have a headache
# Good pick! Hmm.. my favourite movie is Stoker.
# yes i love to keep to look back at memories.
# where would you want to go
# Ah, girls are nice. Are they active? I like to go on walks with my son.
# I do! My favorite is Chowder. Have you ever been out of the country? I have not, but I hope to some day.
# It's nice listening to old music.
# can't say that I have, the process kind of facsinates me though.  do you have experience?
# hahah that's funny. I believe in you though, you can overcome that.
# Huskys are beautiful dogs!  I am sure the kids love him.  Does he shed alot?
# I don't mind the cold so much. Before Alabama I lived in Boston. Winters can be brutal!
# If you like weird psychological movies, you'll love that one.
# my life is great , i'm so happy i'm gonna be a father
# Nice. you have any pets?
# Do you feel it is disrpectful if someone does not make eye contact with you as an adult?
# not in particular - I like all sorts of animals. That's why I started my own clothing line
# LOL.. You can't be vegan and still miss steaksthat?
# I work at the local grocery store, so I know heavy lifting
# thats hard
# I watch 90 Day Fiance which is what has me so suspicious of this guy.  "He" has never actually spoken to or video chatted with her
# I'm just chatting here, but I'm keeping my eye on that ugly spider in the corner.
# Sweet. I'll check it out, and maybe engineer some gear to go along with my internship.
# That would freak me out since I am a bit claustrophobic.  How did you get out?
# i love the Nike Air MAx 270. Those are pretty sweet. Jordans will always be my favorite though.
# agreed laughing is really good
# Yes it is. So many of the kids love talking about their interests and hobbies. It's a wonderful job.
# My favorite thing is taking lots of pictures.
# pepperoni pizza and iced tea are fairly iconic favorites for me to have. i do use a cauliflower crust.
# awesome. how many in your crew?
# what other colors do you do?
# yep
# Awesome! Running is good for the body. Do you listen to music while you run?
# What do you like to do for fun?
# Do you ever do karaoke? I did it on vacation once. It was so embarrassing.
# We are still deciding on the location, have you been any place nice?
# I tried running but it always felt a little monotonous.
# sweet. I have farm animals too, so bottle feeding is a normal thing around here
# What sorts of sports do you enjoy?
# Wow. That's pretty interesting. Me, I like to surf. Well, I'm learning. I only surf at low tide.
# I guess it might have gotten in the way. I sell makeup and cosmetics to make a bit of extra money.
# Sure. Mostly beer, IPA and lager. What are your favorites?
# Yes, I am not all that Zen, either. So CBD works? Do you do the pills or the external cream?
# Not really, He is a male I adopted him actually
# Oh nice,thats a good way to do it!
# That is awesome. What are you planning to do with it?
# She didn't want to get caught, I guess. James was a spiteful little kid.
# What does your favorite team play?
# Oh I bet Hawaii was beautiful. Did you develop a love for pineapples while you were there?
# Please excuse my typos smh. Oh really what video games have you played as a kid?
# It really is another great thing for you.  What other hobbies do you have?
# Sounds cool. Whats your favorite holiday?
# I do.  I took some lessons growing up, we had a piano in my childhood home.
# what is your dogs name ?
# paris! i've been a couple of times
# I take care of them like they are my children. It is difficult but of course I have fun
# Ah yes, in medicine.  That must take a lot of time.  I have a lot.  I am single.
# Damn, how long were you out for?
# Yeah, me too...I'd rather fly.
# Yes, i find it the best way to learn a language is to be surrounded by it.
# I fear some kind of horrible accident. I paint houses for a living so I am always high up on ladders.
# They have great deals on different restaurants but it can also get pricey. I only use them if i'm being lazy.
# Really? Have you ever done it
# And, I did wind up going back and paying for the Coke lol
# That's so great. I think it's important to encourage a love of reading at a young age. It sounds like you're doing a good job!
# My husband actually did the laundry last night.
# I'm asking my girlfriend tonight
# Very true for me.
# Yeah, so was my wardrobe lol
# That's awesome! Were you ever in a marching band or where do you play it?
# No, I didn't have time. I was rushing to work.
# yeah i also like mcdonalds
# Opposite here, have had to work hard nearly everyday since I was 16, but I used to be in the Marines also
# Why? Do they hurt more? Or because they are harder to hide
# I just finished reading a Terry Pratchett book "men at arms"
# Yeah, I always think talking things over with someone is a good idea.
# What can faith do for me, that it didn't do for them?
# Who doesn't?! I have 1 little one actually. I think he likes to swim in the pool more than I do. It's adorable.
# Chicken is on my menu a lot (because of the diet), but not the rice... Is that your main protein source?
# Yeah they are definitely great.. Is pepsi your favorite too?
# It looks so dangerous but like so much fun.
# Nice! Eating defiantly plays an important role. And I'm in the gym every day, for a minimum of two hours. lol
# do you think aliens are real, i'm a big believer
# I listen to classical music when I want to relax or concentrate. What is your favorite opera or band?
# I try, several times a year
# That's terrible!  I'm so sorry to hear that.  How has your recovery been?
# i'm doing well thanks , what is new with you ?
# hmm i gave him some money
# That would be nice, maybe I can do rap songs as I've been told I can sing very fast.
# nice to meet you on here, hope you don't mind if i get to know
# I love Under the Bridge, it reminds me of home, What about yours?
# I wish I was Mark Cuban. I would be rich.
# I am! Kayaking is such a nice way to spend some time on the open water!
# No, I just study them as a hobby currently.
# what is the report on?
# I think it's just the lack of excitement. It always reminds me of elevator music. I like stuff that gets me pumped up.
# I understand that. It was pretty hot here but now it's getting cooler. I love the fall weather
# Yea, none of the people I volunteer with it call it a pound. For some reason, it has a negative connotation! Do you volunteer anywhere?
# I can't help but wonder why she lied, why couldn't she just trust me. I would rather know the truth than to live a lie.
# Have you ever been caught in the middle of a robbery situation?
# I like to read the Bible too
# Awesome. I can't wait to have some of my own one day. I'd have to move to a bigger apartment, though.
# for now i just write and publish my Books
# I think that it will be worth the patience and reward. i just hope i don't get eaten
# And the gateway to better health and a happy life!
# Do you have pets?
# According to my mother she says that sometimes wants to hit someone with a broom. when the kids get annoying XD
# Exactly. I wish I was from a state that has a professional team.
# 5 years . yeah he loves it though .
# It's a full 2 weeks deal!
# I think that's a great idea! Are you planning on starting your own business?
# Wow that's  great i have 8 brothers and we are very friendly
# Yes me to
# Maybe we can go together. When do you expect to be available?
# I love longboarding out there. Especially with friends
# Not that great. It's very irregular and the weather does not follow the forecast. You can't be sure if it will even rain or not.
# I just hope no one overdoes it and stays safe.
# That sounds lovely, also have them bring you to the Caribbean as well
# definitely, i believe in you my dude!
# Of course, hollywood blockbuster are great. What is your favorite movie?
# Does that get boring at all for you?
# yes i like it .the taste of their brand pizza is unique .i loved it
# My favorite drink to make is always going to be apple martinis! Do you have a favorite drink?
# hi , how are you ?
# A chicken Caesar salad is one of my favorites. I also like lighter dressings, not a fan of Ranch and Bleu Cheese.
# yeah i wonder if this vegan thing will ever catch on
# I actually do not play either one.
# Oh that sounds amazing
# I imagine not.  Super slipperly slope, because it will be super expensive and therefore exclusive.
# I do, i'm in Florida so theres a beach within 2 hours of me no matter where I'm at in the state
# Very true. You seem wise and perceptive.
# That would be fun
# I've made a few friends the same way. One of which has now been my friend for going on 6 years!
# agreed . i eat a lot of them . . . all kinds of eggs , actually .
# Wow!  That must be a fulfilling career!
# Pets are important and I'd go crazy without.  Glad you have a dog!  1 dog three cats.
# you got a university planned yet?
# I live in Atlanta.
# yes very true, its my favorite time of year to visit the beach since the weather isn't hot but isn't cold either, what is y0ur favorite beach?
# Do you want a cat, a dog, or something else?
# That is good but i can not say the same for myself.
# are you into music?
# Nice, I have a cat and a dog.
# Luckily I haven't had to many issues with fit, the times it has happened it was something from China
# Oh you wish it were brown, huh?
# cool, I got hit by a hockey puck once as a kid, right in the face, i havent watched a hockey game since
# Mostly animals. I don't have a lot of spare time. I have opened a restaurant and it keeps me super busy.
# I've been through a lot of hard times in life, but I know that God will bless me soon.
# I agree to that. But to experience other things, we need money first.
# yeah exactly, are you religious?
# Seems to be a win-win situation then - I'm addicted to fashionable boots, maybe you can knit me some socks to go with them
# my daughter is 12.
# That would make me more worried. I would try to avoid thinking about that.
# I'm sorry to hear that. Catholic schools are easier as far as wearing uniforms. The suspenders i used to wear in school hurt my shoulders badly.
# Yeah, maybe it is, but I could never say no to Nagini (that's her name!)
# I am lucky enough to be a stay at home mom to my four kids, what do you do for work?
# ya thats good. actually it is good for mental health too
# Oh wow, I didn't know that. It's a strong name to live up to.
# That's great, nice to use a hobby for money.
# at least he helps you . do you cook bake ?
# That's Cool, if you were to attend what would you study?
# Aw, that's so sweet.  Congratulations!  Have any good relationship tips?
# Absolutely! Do you want me to explain the program to you?
# I can try.
# I love that show! I really hope season 4 comes out soon!
# I don't really. I usually end up buying a bunch of random stuff haha
# It's my big grocery shopping day, so I'm actually looking forward to that. Food is my life.
# Yea thats a definite. Do you think the draft will ever make a return?
# That is fair. Veganism is a dietary choice not a religion. But commercial farming and animal abuses are issues that needs to be addressed.
# I like super hero movies. What are your favorite movies?
# I work a registered nurse. Currently I work at a military hospital here in San Antonio. Mostly in the ICU.
# I am going to tell on him, when I turn 37 I'll be able to hire my own contractor
# Me too. I drink coffee pretty much every day.
# I hope. I need to find somewhere warmer to live
# Yes, I have but it's very difficult keeping everyone's orders in tack.
# Ahh, the joys of visiting home. My mom fixed me 3 course meal of my most favorite dishes!
# I should start talking to the animals at the shelter in french so they learn commands in french!
# That sounds like something my little brother would say. I have 3 brothers by the way!
# I've never been there. I need to visit. What would you recommend doing there?
# Just work at a coffee shop while we try to get our band off the ground. I don't have many skills. But Im having fun!
# Doctors said I have Autism, although Im just quiet that's all.
# I do I like to run, I usually run a couple miles everyday. What kind of hobbies do you like?
# like you stream videos?
# i found the recipe on pinterest it i my go to recipe finder lol
# They don't seem to feed them, they appear malnourished and they've had complaints from other neighbors.
# I know.  I met my nieces boyfriend and at first his tattoos were intimidating but as I got to know him I really liked him
# Yep Next Saturday. Really look forward to seeing you. Glad you can come. :) I'm so excited!!!
# Gosh, i am so sorry that you see ghost? I would not want to experience that. Are you ok? I don't feel lucky as far as school goes
# Ballet in London, what happened?
# No! An actual stick.  It was supposed to be a joke! I really didn't find it funny.
# But you switched to something else?
# inside and outside cats.  I like to post pics of them on Instagram with hunting pics
# I have heard of them, they have gotten very popular recently!
# In that line of business you have to keep a god attitude.
# yes, stay calm and get a trustworthy to get a healthy life ever. how about your goals after marriage ?
# Action movies are fun to, I like the really obscure films because you see some really interesting story lines and creativity.
# Sounds good.  Working with kids is not my specialty.  I love to cook
# I tried being a doctor but they didn't care for my blue and orange hair.
# I always get scared to go to casinos because if I do super well I feel like I'd be kicked out
# me too , it has been hard with his death . was gonna go see them in tahoe .
# I live near the Smokey Mountains, so that's pretty and fun to explore. There's also a lot of music, farms/orchards, breweries, and some dams/rivers
# I'm withholding judgement for now. I think Linda Hamilton is a badass so I'm in for it
# that's cool ! i work for the government . do you like sports ?
# Death of a Salesman.
# I try to incorporate the metal in the commercials I work on when possible
# Oh I love the guitar! Do you play acoustic or electric?
# Yes I walked in and there was a line of puddles behind me
# yes it is it can also come bending the wrong way or not right in bed.
# Yes
# It's pretty good, but I don't have to spend money on gas. My daily driver is a bicycle that I pedal with my hands.
# Find a school to get your CDL.  You can usually get it done in a few weeks.
# I did, when I was 16.
# I also enjoying riding my mountain bike when I go camping. Do you enjoying camping?
# Yes, it can be quite awful. Thankfully I didn't experience it with either of my pregnancies. Could you do anything to help your wife?
# I turn 40 tomorrow.
# I hit a bird one time while driving 70 mph.
# Do you make jams or preserves out of them?
# Yea but it's not the same as in person
# it sure does. Do you party a lot?
# Alright. It is true I am vegetarian. I was testing your knowledge.
# Yes, it was.  Were you ever in a spelling bee?
# japan would be a cool place . i am actually going a cruise out of the country next month .
# what  kind of movies do you like
# My sister is moving in with us because she lost her house.
# I wrote a short story in high school.  My instructor though it was good and entered it in a contest.
# I went to cosmetology school and didn't do anything with it
# Yea i sure will, do you have any great tip i can keep in mind?
# Just go to the ones without animals please :) They are kind of abused.
# She lives in queens.  Her and I love to play soccer in the park to get fresh air.
# Oh what a coincidence! It's such a fun place to live, but crazy expensive.
# O ok no i have never heard of her i dint think.
# I'm not sure. I just remembered that fact.
# What are some of its attractions
# I'm going to buy new decorations for Christmas - I just love decorating for the Holidays!
# We have a golden lab, but he's about 14 right now, so he has no interest in running. haha
# You only live once, it's a quote to do crazy thing or whatever you want.
# I had my parents paint my room blue camo for me when I was younger I enjoyed hunting even then
# True. It does make me a littl sad that my Grandmother's blanket might be ruined now though.
# What's even more surpising is I have crashed my CAR 2 times as well.
# Yeah, cleaning after my two kids are tough, but I think cleaning up after a dog is easier.
# I never learned really until I taught myself a couple of years ago. Never got the jist of it though. I hope you and your dog have a great life.
# That is awesome basketball is a fun sport to watch and fun to coach (I coached it for 25 years)
# i don't think about it. it has always been this way
# Did you drive any toyota vehicle 2019 model?
# Unfortunately one of my kids got sick so we had to cancel everything.
# I really enjoy drinking coffee and people watching. How about you?
# Yes, but in the big picture I guess it doesn't matter much!  Do you like to cook?
# wow, that sure is a lot of tea. how do you sleep with all that caffeine running through your body?
# where do you live?
# yes i do and i am from Georgia we love football
# I'm not the biggest fan, but my dad loves it. I sit and watch it with him while eating our favorite food, jello.
# My boyfriend always does thing thing that gets me so jealous.
# i drink a lot of beer somtimes. is it bad?
# I went to an musical competition. one such a Musical voice is repeating in my mind from yesterday.
# We both work in predominantly male professions, that's cool. I'm glad there are more women out there like me!
# Where is your favourite place to go to have some sun?
# Definitely. I love to take breaks at gas stations and read books from many series.
# thanks for the advice.  I think it will be my best route going forward.  I need stop worrying about it and get back to my project
# That's so exciting. Nutrition is such an important subject and I don't think people pay enough attention to it. Good luck!
# Interesting. Do you like watching it on television or just playing/
# i am a vet at the local emergency animal hospital
# I'm impressed with how far technology has came in the last 10 years!
# i had a really exciting lunch the other day would you like to hear about it?
# That's very true. I am glad that such restrictions are starting to fade away. Cooking, whether traditional or brewing, can be enjoyed by anyone.
# asian dogs i have. they are very cute. do you have any?
# Do you instruct yoga sessions?
# As long as you follow your dreams, you'll do great things.
# I've always wanted to go to school to be a mechanic and have my own shop one day.
# Yes, wild beaches are the best. Which do you want to visit?
# I may just have to sit down and try it out!
# Like we talked about earlier I haven't had much time for games lately. It's been a long time since I've been able to play.
# You prefer the ones that have been sanitized for human consumption?
# Well you know guys have there way with words!
# Have you ever thought of going into this field?
# I was sly at first and then I went in for the kill at the end!
# Awesome! I head up to Canada at the weekends. I love the views there.
# I like to read fiction, usually apocalyptic fiction and dystopian as well
# That is very relatable. Though, even online I find myself second guessing how I come across to others.
# well I better get going...my family has seasons tickets to see the Bills so we're planning a trip to buffalo this weekend
# what is your favorite romance novel?
# wow 700 million worldwide that is a huge success.
# I won't work there forever, but I might be too old when I leave lol
# Wow that's fantastic. When I retire I'd probably just sit around playing video games and sketching Disney characters
# Yes little Tasha loves music very much
# That sounds really fun.
# So I have been told. I like using the old stories the best.
# What color is your car? Probably not pink!
# lol. dogs are the best. :)
# That's cool! I like playing football and reading.
# What, so you just fake your personality now?
# I hope so! What about you?
# Jay-Z, J. Cole, Travis Scott are a few.
# That must have been stressful on you, as well. My mom has gotten a lot better with age.
# That's cool, what sort of volunteering?
# Oh yeah, who is your favorite character?
# No just 3 iguanas that are awesome
# Yep! Its always been loud around here haha
# Thats the truth. Soccer mom huh? How is that like?
# is orange your favorite color?
# I felt pretty good about this past weekend. I had a date I was looking forward to it
# I'll probably go pro. We could have gone to state if coach just put me in. I know we could have.
# Same here. Can't eat barbecue with tight pants!
# Even my bother also doing the same thing . Some time I help my brother for his work
# While my job doesn't pay a lot, it's very rewarding. I work as a caregiver and it feels  so good to make someone happy.
# Well seeing as I reffered to her as "she" in my first sentence but named her Ted three sentences later I had to improvise a bit.
# Eh...my mom and dad are both red headed, and I tell bad jokes on purpose to tick them off.
# I do like that stuff.  Do you like ghost stories and such?
# Yes, I'm only 15.
# I mean I
# Well thats me. It was hard growing up without siblings but at least I was able to focus on my ballet.
# I'm sure it will be the first and last things I do...the good news is that I like going to museums in my free time
# Maybe one day I will get to try it out!
# That's true.  There aren't a lot of dog facilities at the beach unfortunately.  I've got a small Beagle.
# I help with a local food co-op and a community garden
# Oh wow! Was it a really big culture shock to move away? I myself have never lived anywhere but the states.
# well at least theres that. I hope he choked on that burrito
# You can get it at any arts and crafts store. There's a variety of colors too so you can make a sparkly mini cactus vase if you want! Lol!
# Yeah but I had spent extended time in the U.S. before. Still very different though!
# have you had McDonald's new XL burger with grilled onions?
# Have the leaves started changing color up there? They are just starting to change, I love colors, especially the shades of orange.
# yes some  Like bad dreams
# that sounds amazing ! my parents disapprove of my lifestyle so they would probably hate the road with me .
# if you are sensitive to scent, bath salt would be he best idea
# That sounds like a lot of fun. :) I love Halloween but I just had surgery, so no fun for me.
# same, i  am wondering if opening a restaurant catering to vegan/vegetarian would be a hit? i am starting a new juicing bar though, do you juice?
# I love cheesecake. And pumpkin pie. Those are my 2 favorite desserts. Do you cook?
# Hahaha. But if there was stricter gun control, the psychopaths wouldn't have any guns, right?
# i am alright . trying to get motivated to get off my couch .
# Sounds like a plan! I'll get some wine chillin' and put together some nasty snacks to stuff our beautiful faces with!
# No because I had to my dog behind so we were both very worried about him
# i have a small garden myself
# How many live at home?
# ll . that's almost exactly what my youngest son owen said to me yesterday .
# Yes, I grew up near Lake Michigan, my father was a lake cop, so we could go out all the time.
# Agreed, I'll have to try getting back into it.
# I don't have time to play games, I have to donate blood monthly in honor of my sister who died
# Is Goodwill actually sponsored by the United States government?
# That sounds amazing! I've actually never been before, but it sounds great. I wonder if there are any peaceful places to clear the mind and write?
# I don't think I could ever do that. I love my job too much to ever give that a try!
# I can't say i have, what about yourself?
# i would rather starve than eat mcdonalds
# Yes! That's why i decided to only start taking the bus from now on.
# This is very true. You sound like a philosopher.
# I am a huge fan of Nintendo as well.
# What breed was she? I though MaineCoons were about as big as they get! My boy cat weighs almost 25 lbs!
# These kids kicking and screaming and cursing at their parents in stores these days etc... It's like they expect the public school system to raise them for them
# I'm a little insecure, so I feel funny telling people that I like Britney Spears.
# I like her more country stuff. It's nice to listen too on walks outside.
# Wow that sounds fun.. I play basketball while waiting for my wife to finish cutting clients hair somedays.
# Yes, as a child. I grew up on a large farm so we had lots of places to fish on the land.
# I don't know how to sew.
# That's understandable. I enjoy taking walks and seeing my family. Very busy though so don't get enough time to do it recently.
# What are your favorites?  My mom is best baker in family. We love eating her cookies while watching old movies.
# It helps keep the peace!
# It sure is. I often miss them since I live in different city. But making new friends always helps.
# that is true.  but i find myself losing self control and buying a lot more than what i need
# I guess I should give it a trial too
# Do you prefer TV and movies to books?
# I'm the youngest out of 4 of us. I have two older brothers and one sister who is a year older than me.
# Recently, my dad gave me some money to buy e-cig liquid for my vape, I am very thankful!
# ok cool, so how many languages do you know
# Awesome, what position does he play?
# Did you train yourself or did you take classes?
# It's just minor but you can tell at certain angles
# That's great!  What is your favorite breed of dog?
# Nope, i'm too old and obese, so I retired.
# yeah, it's really nice to be able to cover my bills and such in just three nights a week.
# What do you remember best about him? I know lots of people think "happy little trees"!
# Inspiration means being the force or influence that inspires someone to do something or to feel a certain way. i can inspire from my mother
# What's the dog's name?
# I haven't yet, but I'd like to try. How about you?
# That's cool. If you had enough money to get one of the cool ones, would you get yourself a snake instead of a dog or cat?
# Yeah, you're probably right.
# alfredo is the best do you make it from scratch?
# It is not lol, restoring mine almost cost me a liver that and paying for college, it was worth it though
# nice . almost forgot to feed my lizard . the name is gila .
# I told my son repeatedly to do the dishes, but instead he played video games all night and never got them done.
# yes, I think so
# i like buying clothes and household items
# I eat enough replacements not to miss it haha
# I live in Delaware. I drive a black car but it gets dirty quickly being near the beach
# me too. I like going to gigs with my friends. Have you heard or seen anyone good lately?
# Is fly fishing pretty easy? I love to fish, but, I'm 70 so I take it easy.
# yup! the next day my tire blew out also
# Yes i need some time off from the kids, it adds up!
# You should try the recipe on the Toll House chocolate chip bag sometime.
# I like giving lessons, but it depends on the student as to how much I enjoy it.
# I do. I have traveled only traveled inside of the US though.
# Yeah Thanks for the advice! Do you play anything else?
# Nice good to know that! Do you like them?
# Huh, that's interesting.  I usually associate it more with Australia.
# I moved to Texas, but it wasn't my first choice. I am living with it though!
# I used to buy them at specialty sporting good stores but now I just use the internet
# I like the color of yellow reminds me of corn on the farm
# Do you get together for holidays?
# Mostly sports games,I try to get my classes and studying out of the way What do you like to do?
# I don't usually remember the names to be honest. Or do you mean Hollywood actors?
# Women in this part of Texas must be deprived of outsiders...because I get sideways stares from all the Latina ladies when I walk into any gym, bar, or supermarket and it trips me out
# Yeah. Sometime its very difficult to handle her.
# My brother just got a new job, and he and his family are moving into a bigger house in a nicer city. Kind of wish I had his success right now, but I'm struggling to remain proud of him too. I don't want to make it all about me.
# NEVER lol. But some people ;) Although I just saw how chocolate was made and it is a bit gross.
# So far I haven't had any issues with online payments, perhaps I have just been lucky so far.
# Which one is your favorite?
# I prefer online shopping, except buying shoes. It just difficult to buy shoes online that fits you perfectly. How about you and online shopping?
# wow!! do you get any snow there?
# I love dogs, I am actually thinking of starting a labrador rescue.  Do you have any pets?
# I hope you do also. What made your day busy?
# That's great, hopefully those meeting have led to very successful outcomes.
# that sounds great, I make a pumpkin cheesecake sometimes.
# I would definitely encourage it. My adopted dogs are so good, my students love to come and visit me to see my pups
# Yes, it will be very rewarding!
# Usually mountain bikes, sometimes I bring my three dogs along for the ride. How about you/
# I put in vacation request since January for next week. And now they're telling me they're too busy to let me go.
# Wow that sounds exciting, I've never done skiing before. Is the equipment expensive?
# Yeah, that is good stuff. We have a few good local spots here, but none like when I lived in CA.
# amazon and costco
# They are protected by the dunes which are some of the largest that I have ever seen.
# It's not just her music but watching her go through so much junk then growing up and maturing
# Yeah Drake is cool but I would have to agree with you about Nas being in my top 5 rappers of all time
# I know I was just kidding, they are my favorite band.
# i agree. we do a lot of hand print paper ornaments as gifts for the holidays as well..thanks for the new idea
# study hard and always have patience, that will definitely help one day. where do you live
# I envy your winters but not your summers. My wife is from India so we eat lots of spicy food.. I love it!
# Same with me. Alcohol usually has a nasty taste to me. Are you in school right now?
# The person at the Registry who was taking my information was very annoying
# I have never heard of them! I know a lot of indian food is vegetarian!
# I really wish it had gone on for a few more seasons.
# Yeah. most bands are like that when they try to stay relevent.
# i found it in my garage when i moved in .
# Do you have any marketing or sales experience, by chance?
# Oh i'm so sorry to hear you were hit by the hurricane, was this very recently?
# What are your favorite bands that you've seen at a concert?
# i hear the people are super nice and make great cupcakes , which i love .
# I was an RN, but my best friend was a LPN before she left the field.
# I have several small dogs.
# That's too bad.  Does it make it difficult to do your job?
# Are you getting married traditionally in a church or some other location?
# Oh yeah, I can relate to that, has it been snowing a lot where you are? My family and I always wait until it's warm to camp.
# I prefer a fake white tree, with one specific color theme every other year.
# Heck yeah! Best way to retire ever, we can work out in the pasta shaped pool
# For sure. England is rich with music history.
# I hope they will. I do miss them. I hope they will listen to me when I say I just want things to be calm and informal
# That's a thought.  I'm a decent writer, and have a pretty good imagination.  What's your favorite genre of writing?  It could give me a kick to get started :)
# I enjoy rock music too, but my marriage and children take up a lot of my free time.
# It some areas, they say don't wear anything shiny and they'll be more scared of you. But on shore it was beautiful!
# The next one should occur on Nov. 21 2021. Not to far away
# That's pretty sweet. Mine was a '78 VW Camper Van. Lime green with a plaid interior. I loved it, but I didn't know how to work on the engine.
# Wow! interesting lol.
# Ah, you have branded glasses? That's very cool! What color are they?
# some times.. managing people is not fun always..
# I hope so to!!!!!
# I have really been shocked at how cool some of the people I have met on the internet are.
# my brother was in the hospital really sick
# I know! I have a terrible memory.
# I imagine most of them would, i've never been terribly well coordinated.
# I do! I have a little dog. Are you a photographer?
# A Mustang GT, convertible
# Generally just working out and stuff, and spending time with my family
# Very basic, I love Mexican food. Anything with a lot of spice, most specically though I love shrimp tacos
# did you watch end game
# I like a bit of everything. Classical is always wonderful but lately I've gotten very much into musicals like Hamilton and Greatest Showman.
# With veganism you don't eat any animal products, including butter, milk, eggs etc.
# Yeah, that's fine. I'll be out surfing during the day, so come over when ever you feel like.
# Sorry I am not famaliar with film " The Great Car Race" I will have to look it up. Was it a good movie?
# ...
# my dad does the same for 11 hours a day
# It can be scary to think that way
# They finally did after middle school.
# nice. favorite album?
# Brickoven no doubt. But I really don't discriminate.
# My coworkers all went together and gave me an expensive gift card."
# I love that Percy the Pug.  Mine are Wine and Cheese.
# I have never seen that movie, anygood?
# That's a great hobby. I like to do gardening, its fun! Have you made any cool drawings lately?
# That's a thought. I wonder what the weather is like there.
# i think that is great parents always influence their children
# Nice man, same. What's your favorite band?
# It's rough, right? I haven't worked a single day in my life. What about you?
# that was sad, i live in hyderabad
# i where them when i get books autographed , that's the only autographs i like
# The other day one of my dogs found an injured bird in my backyard!
# i have only been once and i slept thru barber of seville
# Sure - I'll beam it over. lol Do you brew?
# about 2 years now what is your novel about ?
# Aw I love beagles! I have 3 small dogs. A pug, and 2 yorkies.
# Oh okay. We call that fruit salad where I come from. :) Yum very good stuff.
# yeah i think that is a good idea. I could sell them and buy something cool. any ideas?
# That's fun. What else do you like to do?
# My uncle was a drunk but i still loved him, he died walking to by beer and the irony is he got hit by a drunk driver that always makes me feel sad thinking about it
# So what's your favourite hobby? Mine would have to be going to the gym!
# Yeah I'm a big fan of video games, Ive been playing them since I was a kid.
# Hahahahah, Thats good! I guess I have to take the subway home! Talk about a footlong walk!
# Wow, I have blonde hair as well!
# I have a neighbor who sits outside all day and it's across from my backyard so I can't sit and relax and watch the birds.
# No, but your last message said you hunt lizards.
# that's awesome . what kind of nurse do you want to be trauma or something else
# Oh wow! That sounds complicated! Bet your family always ask you for tech support ahha!
# That's so cool. I like romance too, but I spend more reading on motivational stories and autobiographies.
# So what made you switch?
# Definitely. Thanks for listening to me, really means a lot
# are you in college ? i graduated a few years ago
# O my how interesting. What part of the world?
# well , hiring people is easy ! did you know that my wife is miss usa ?
# Where did you live before moving there?
# I do actually, I am planning to take a traveling trip down the coast of Western Africa to see all the beaches.
# My favorite thing to draw is Anime.  I haven't really taken it seriously enough to make any money from it, its just my passion
# Hahaha.  That's funny.  What sort of stuff do you read?  What does your cat like?
# no i do not have much time to fish at lakes because i am busy at the large law firm i work at
# Heck yeah.  Are you a fan of the blues?
# I went to a restaurant where they cook in front of you and it was very cool! I had some teriyaki chicken
# me too never been yet. my job is busy i am up 4am everday how about you?
# That's cool. Do you like music?
# That sounds nice. I live in the country too, with my cat.
# Not as fast as Jeff Bezos can monopolize the shipping market! :D
# Nice to meet you. Do you ever go skiing with your family?
# I am origianlly from Finland, but have lived most of my life in the United States.
# yes do you have any
# It's crazy how much better a pickup can be compared to a sedan
# what is her age
# It really is.  I know that's how i'll get through this.
# I do as well! I always pack sunscreen for my picnics
# So, the other day I had a test of my character.
# haha! do you like the stock market? I like to invest more than i like sports
# philosophy a cool discipline for people who can think
# I tried to make small talk at my new job's onboarding and the lady ignored me.
# I like Indie music too. Though many small bands have to become quite commercial to succeed in getting their music out.
# Oh, I love lasagne. I make my own noodles as well as the sauce.
# Yes. I lost my mother in an airplane accident when i was just a child.
# what can you cook
# He is really sweet I just loved the effort he put into the gift
# So what? I even dont care if I dropped out from school.
# I love experimenting with all kinds of different cuisines. Lately I've been cooking a lot of Indian food. What do you like?
# Lol. You're supposed to have more veggies, not less. Eating properly is difficult sometimes...
# I understand! What are your favorite activites here?
# Yeah, we're pretty close, but I think I like her more than she likes me.
# yeah it's my job to help people travel around the world, so maybe I could send you to a country with tiny spiders to help you stomach it
# i love my kids I build them an arcade with a few hundred snes games build in
# That sounds so cool! I work in finance, so there really isn't all that much excitement going on lol
# Do you feel you have a strong urge to use your hands?
# It's fun to people watch at the markets. Have you been to any festivals?
# With things getting more progressive though she may be able to play football when she gets older too! We do play catch
# they love to play but they can get rough not meaning to
# To retire? Or just to go visit?
# Or anything really, I am constantly working on my rig. My two passions in life, chickens and truck driving
# you will get there . i'd love to use more of my george foreman grill
# Oh yeah, I'm a fiber artist
# No, I've never tried that before. Have you? What is it like?
# That is interesting. Did Al Gore take credit for the internet?
# i live with my dad, but i hardly ever see him. he works at a busy ad agency on madison avenue. what does your father do?
# Here I am, another night all alone. You ever feel like you will be alone forever?
# Cooking. I love making Italian Food
# Really? How long you have been running marathons?
# sounds very cool
# Sure its something great to shout about.
# I will try that. I am going to have these braces for a while so I might as well make the best of it.
# Oh man! Did he have a ruptured disc? That is what I had
# That would be really funny but too cruel. I love my dog.
# no and no - that was unfortunately the end of that relationship
# I also like it.
# Yeah, the colors are starting to get really inspiring, seeing your breath and getting some exercise. It's great!
# I live in a big city anyway so I don't believe there would be much point for me to go. Do you believe I would experience something unique there?
# Months ago. Sometime in summer
# Really? I didn't that was still a thing. Like what DJ/band for example? I like Skrillex but that isn't techno.
# nice . i guess they didn't hurt as much as i think they would
# I do.  I'm married with two boys.
# Haha I am glad I am not the only one. What part of law do you like the most?
# my favourite too
# Yes, raising the money was tough. Hard for people to take you seriously sometimes when you have purple hair!
# That's awesome. Yeah, I collect stamps.
# Ever since I was a little girl I've been obsessed with fashion. What kind of things do you like to do with your friends?
# Amazing. We have the same kind of job. Do you like it?
# Have you been to Mexico before?
# i'm good thanks for asking
# Italy is such a wonderful place. I bet people visit for the food!
# I am fair skinned so can only go early morning or late evening. I watch it on my computer there is a web cam
# Sweet, I make clothing and bedding too.
# How old are they?
# There are plenty of clowns at my circus to choose from.
# dang , sounds like a good american family . i'm from kentucky .
# they were when I got them,, but they are now over 7 years old ,,, very cute
# I totally agree! Dogs can be a bit much, and not nearly as good in a stir fry IMO. They are quite loving though!
# I made a great pizza last night
# Mainly monsters for games, whoever pays to be honest! lol
# 10 so far.  do you have any?
# sure do
# It was a little frightening. I took the dogs for a walk at the park and I'm good now.
# It could just be that I love bubblegum. My friends actually used to call me that as a nickname.
# a year after i got my teaching degree
# Well I gotta have money for that which means a job.
# I'm not a singer, I play the guitar.
# I'm a student, which is great for now. Gives me time to hang out with my friends. What do you do?
# I like to be frugal in my life
# I like to travel and explore the wilderness.
# I took a one day train from Ohio to Pittsburgh and back. It was fun.
# I agree.  Do you have a favorite color?  Mine is red.  I even have a red truck.
# I love to ride my bike. Exercise is so good for you.
# i moved to panama city beach florida
# My daughter has been sick and I've been taking care of her.
# That's great, my mother wanted me to be a trucker when I was young :)
# Well thanks! that makes me feel good!
# I love pasta. That sounds like a fun thing to learn how to make. I bet your boyfriend is happy that you're learning!
# That is so interesting. How long did they rule?
# That's really nice .because it's help you in your future..
# Do you like any rapper?
# I was at the mall and smelled a cologne that my ex used to wear. It brought back old memories
# Are you by yourself or with family?
# thats nice I hope she has a good birthday. R u having a party for her?
# thats cool! What kind of music do you play?
# I just can't wait until this weekend! I am going on a trip to the Bahamas for a week! I can't stop thinking about it!
# iphone. I feel the apple ecosystem is really nice
# I guess you don't get snow in Florida?
# No, not yet. I haven't seen her since.
# Somewhat this stuff aint easy.
# Oh I can already see the chaos that could be! I would want to call out on that day!
# yea making clothes is always really fun
# that is great , me and my dogs live here in new mexico
# Well it's hard to think of a funny one just off the top of my head. Knock knock!
# I own my own salon as well, business has been great lately.
# nice , i went to the renaissance fair today and did cosplay
# at least I enjoy it...I couldnt imagine if I didnt how bored I would be
# Alright that's fair enough, any plans of maybe moving out and buying one?
# I prefer data sciences. It is not for everyone that's for sure. Not as fun as psychology!
# i do actually ! i have 7 . i am only 19 years old .
# my favorite place is the beach
# Yes, I actually do a lot of online shopping.
# Do you like catching funny moments? Those are my favorite.
# A small town in California named Bridgeport.  It was so expensive in LA that I once lived in a storage locker for 2 months to save money.
# I am also allergic to shellfish. It makes eating out very frustrating.
# Yeah i know right..Maybe Ill go today, who knows.
# i can always help with music
# One of my classmate shamelessly asked me to copy my homework and submit as his own. So disgusted at his behavior
# you should get one. it's a great way to express yourself. do you live with your parents?
# me too . especially the families . it would be hard for kids to lose their parents .
# great ! just came up with a new recipe for my cookbook .
# hi i can not have any hazel nuts .
# My brother offered to drive me to the doctor today. I had faith in him
# I am in a coworking space, so it is pretty loud
# Okay, where do you fish? Pacific, Atlantic, Golf Coast, Red seas, Alaskan?
# There's a place for them, but they get overused. My kids can play educational games but only for a small portion of the day.
# Oh i agree! My German shepherds love my vintage styled one!
# It is an amazing instrument, who invented it?
# But I am interest in music.
# I don't understand why it's so difficult for people to pick up after their dogs.
# Cats are fun too! But I still prefer dogs.
# Just locals! nobody famous! like houdini or something!
# 26. Good to keep healthy! Recently I like buying phone accessories and electronics
# I was born there!
# Yeah when the car is done things will be different, hope that day comes soon
# I prefer to play over watching.
# yeah sure very warm and durable
# I would love to visit Turkey and have a Donner kebab sandwich.
# I didn't at first, but moving here there's only mexican food, so you get used to it
# it was a hot air balloon crash. They always enjoyed the little things in life, it's something they passed down to me
# I am Vegan!
# Right? Typically a bit better then the stuff you'd normally find out there.
# Its a Indian restaurant, i would work there now but i volunteer at a soup kitchen
# One of them! I would say bacon is my favorite. What is yours?
# a rock
# yes , i used to be an actor , however i retired , did not like it
# Do you enjoy eating out at restaurants?
# Do you think there is beauty in the sadness of her poetry?
# Well my power went out yesterday before my shower and before I had washed my clothes. So I had to run up to the fast food place- walk- and try to contact my mom. It made me a bit embarassed going outside in dirty clothes with wet hair.
# Yes, that is for sure. They are popular because of their good temper and aren't known to pass down health problems like other breeds are known for.
# No it does get harder as you get older.
# i am proud of myself too
# My husband does, but they are not my favorite.
# Always! I like it in coffee ice cream, mixed with coffee. Then I get twice as much.
# i don't have a dog, but i would really like one. maybe a golden retriever or a smaller terrier dog
# I love Chris Stapleton, nothing beats Tennessee Whiskey
# I live on a 3rd story walk-up. Does that count?
# Not true! There is no such thing like thta.Art is art,regardless what type it is
# there is this guy that always comes in my store, he is an older man, i think he might be homeless. he always asked for napkins and a glass of water
# No, maybe I should do that. That's good advice, thanks. What are your interests, religion or otherwise?
# and you probably gained somewhat of an accent haha
# Yep its nice to stop thinking about all those numbers and just have happy little thoughts
# The only meat I really like is chicken, so it won't be too much of a sacrifice, but I'm worried what I'll eat to get enough protein.
# It does!  And my seats are so comfy!
# No, I don't, but that's a fun nickname
# I understand, there is not enough time to know everything about Autism, learning a second language will make a stronger bond
# I grew up around most of my big, extended family but now we are all over the place. I just recently came here to Vienna.
# Eh, it's no biggie.  I actually love stormy weather.
# It's not very good on gas mileage
# What breed is your dog?
# once in a while, history is good
# What is your favorite energy liquid?  I'm a traditionalist chugging the coffee.
# Me too but only once in a while for me.  I need my veggies to feel good.
# I just said my daughter is really into drawing right now, I can't keep up with how much paper she goes through
# Yes, it's one of the few that don't have counties dumping waste water into it. I love it.
# What do you like to do?
# She is somewhat.  You know how the grass is greener?  While I'm wishing I had her job she said she is envious of my new job.
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/callbacks/model_checkpoint.py:606: UserWarning: Checkpoint directory /content/drive/.shortcut-targets-by-id/14d-pENWXcgaQmAVFwXnQlaiaxGFRk-AV/CS425-NLP project/datasets/BART-dialogue generation/checkpoint_files_2 exists and is not empty.
#   rank_zero_warn(f"Checkpoint directory {dirpath} exists and is not empty.")
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name  | Type                         | Params
# -------------------------------------------------------
# 0 | model | BartForConditionalGeneration | 139 M
# -------------------------------------------------------
# 139 M     Trainable params
# 0         Non-trainable params
# 139 M     Total params
# 557.682   Total estimated model params size (MB)
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=3` reached.

# %%
def generate_reply(model_):
  # Put the model on eval mode
  model_.to(torch.device('cpu'))
  model_.eval()

  conversing = True
  while conversing:
    txt = input("What's on your mind?: ")
    if txt == "Bye!":
      break
    line = [txt]
    prompt_line_tokens = tokenizer(text = txt, max_length = 32, return_tensors = "pt", truncation = True)
    line = model.generate_text(prompt_line_tokens, eval_beams = 4)
    print("FRANKLY: ", line[0].strip())
  print("FRANKLY: Have a great day ahead! \n")

# %%
generate_reply(model_ = model)
# Say "Bye!" to exit (Case-sensitive)
# Out:
# What's on your mind?: my name is faith
# FRANKLY:  That's cool.  What is your name?
# What's on your mind?: i am faith
# FRANKLY:  That's great.  What do you do for fun?
# What's on your mind?: i play with my dogs
# FRANKLY:  i love to play with my dogs
# What's on your mind?: Bye!
# FRANKLY: Hope you are feeling better. Have a great day ahead!
